# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ses

# %%
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### 1. create a bar plot for count the frequency of the three species.

# %%
### code here
ses.countplot(x='Species',data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
#  the above bar plot shows that All species have same frequency

# %% [markdown]
# ##### 2. Create a pie chart to show the percentage of species.

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
f=df['Species'].value_counts()
l=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
plt.pie(f,labels=l,autopct='%.2f')
plt.show()

# %%
# From the above pie chart we ccan see that all three species have equal persentage in the given dataset

# %% [markdown]
# ##### 3. Create the joint to all numberical variable for analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
d=df.select_dtypes(include='number')
d.drop('Id',inplace=True,axis=1)

# %%
d
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
ses.scatterplot(x='SepalLengthCm',y='PetalWidthCm',data=df,hue='Species',ax=axes[0][2])
ses.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=df,hue='Species',ax=axes[1][2])

# %%
fig,axes=plt.subplots(figsize=(15,10),ncols=3,nrows=2)
ses.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=df,hue='Species',ax=axes[0][0])
ses.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df,hue='Species',ax=axes[0][1])
ses.scatterplot(x='SepalLengthCm',y='PetalWidthCm',data=df,hue='Species',ax=axes[0][2])
ses.scatterplot(x='SepalWidthCm',y='PetalLengthCm',data=df,hue='Species',ax=axes[1][0])
ses.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=df,hue='Species',ax=axes[1][1])
ses.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=df,hue='Species',ax=axes[1][2])
plt.show()

# %%
###  from graph 1 : for the we can clearly see species Iris-setosa sepal width incerase as its sepal length incerase
###  from graph 2 : for the we can clearly see species Iris-setosa petal length incerase as its does not incerase sepal length
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %% [markdown]
# ###### 5. Create a Boxplot or Whisker plot as univeriate and bivariate analysis.

# %%
ses.boxplot(x='SepalLengthCm',data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
ses.boxplot(x='PetalWidthCm',y='Species',data=df)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Species'>

# %% [markdown]
# ###### 6. Create a Strip plot

# %%
### code here
ses.stripplot(x='SepalLengthCm',data=df)
plt.grid()
plt.show()

# %% [markdown]
# ###### 7. Create a Violin Plot.

# %%
### code here
ses.violinplot(x='SepalLengthCm',data=df,hue='Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %% [markdown]
# ##### 8. Create a pair chart.

# %%
### code here
ses.pairplot(df,hue='Species')

# %% [markdown]
# ##### 9. Create a Heat Map

# %%
### code here

ses.heatmap(df.corr(),data=df,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 10. Create a distribution plot for all numerical colomns.

# %%
### code here

# %%
ses.histplot(data=df,x='SepalLengthCm',kde=True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
ses.histplot(data=df,x='SepalWidthCm',kde=True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
ses.histplot(data=df,x='PetalLengthCm',kde=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
ses.histplot(data=df,x='PetalWidthCm',kde=True)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>
